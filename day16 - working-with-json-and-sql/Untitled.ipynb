# %%
import pandas as pd

# %% [markdown]
# ### Working with JSON

# %%
pd.read_json('train.json')
# Out:
#           id      cuisine                                        ingredients
# 0      10259        greek  [romaine lettuce, black olives, grape tomatoes...
# 1      25693  southern_us  [plain flour, ground pepper, salt, tomatoes, g...
# 2      20130     filipino  [eggs, pepper, salt, mayonaise, cooking oil, g...
# 3      22213       indian                [water, vegetable oil, wheat, salt]
# 4      13162       indian  [black pepper, shallots, cornflour, cayenne pe...
# ...      ...          ...                                                ...
# 39769  29109        irish  [light brown sugar, granulated sugar, butter, ...
# 39770  11462      italian  [KRAFT Zesty Italian Dressing, purple onion, b...
# 39771   2238        irish  [eggs, citrus fruit, raisins, sourdough starte...
# 39772  41882      chinese  [boneless chicken skinless thigh, minced garli...
# 39773   2362      mexican  [green chile, jalapeno chilies, onions, ground...
#
# [39774 rows x 3 columns]

# %%
pd.read_json('https://v6.exchangerate-api.com/v6/212374dfd3ab49de9a2dbff9/latest/USD')
# Out:
#       result                          documentation  \
# USD  success  https://www.exchangerate-api.com/docs
# AED  success  https://www.exchangerate-api.com/docs
# AFN  success  https://www.exchangerate-api.com/docs
# ALL  success  https://www.exchangerate-api.com/docs
# AMD  success  https://www.exchangerate-api.com/docs
# ..       ...                                    ...
# YER  success  https://www.exchangerate-api.com/docs
# ZAR  success  https://www.exchangerate-api.com/docs
# ZMW  success  https://www.exchangerate-api.com/docs
# ZWG  success  https://www.exchangerate-api.com/docs
# ZWL  success  https://www.exchangerate-api.com/docs
#
#                                terms_of_use  time_last_update_unix  \
# USD  https://www.exchangerate-api.com/terms             1773273601
# AED  https://www.exchangerate-api.com/terms             1773273601
# AFN  https://www.exchangerate-api.com/terms             1773273601
# ALL  https://www.exchangerate-api.com/terms             1773273601
# AMD  https://www.exchangerate-api.com/terms             1773273601
# ..                                      ...                    ...
# YER  https://www.exchangerate-api.com/terms             1773273601
# ZAR  https://www.exchangerate-api.com/terms             1773273601
# ZMW  https://www.exchangerate-api.com/terms             1773273601
# ZWG  https://www.exchangerate-api.com/terms             1773273601
# ZWL  https://www.exchangerate-api.com/terms             1773273601
#
#                 time_last_update_utc  time_next_update_unix  \
# USD  Thu, 12 Mar 2026 00:00:01 +0000             1773360001
# AED  Thu, 12 Mar 2026 00:00:01 +0000             1773360001
# AFN  Thu, 12 Mar 2026 00:00:01 +0000             1773360001
# ALL  Thu, 12 Mar 2026 00:00:01 +0000             1773360001
# AMD  Thu, 12 Mar 2026 00:00:01 +0000             1773360001
# ..                               ...                    ...
# YER  Thu, 12 Mar 2026 00:00:01 +0000             1773360001
# ZAR  Thu, 12 Mar 2026 00:00:01 +0000             1773360001
# ZMW  Thu, 12 Mar 2026 00:00:01 +0000             1773360001
# ZWG  Thu, 12 Mar 2026 00:00:01 +0000             1773360001
# ZWL  Thu, 12 Mar 2026 00:00:01 +0000             1773360001
#
#                 time_next_update_utc base_code  conversion_rates
# USD  Fri, 13 Mar 2026 00:00:01 +0000       USD            1.0000
# AED  Fri, 13 Mar 2026 00:00:01 +0000       USD            3.6725
# AFN  Fri, 13 Mar 2026 00:00:01 +0000       USD           63.3259
# ALL  Fri, 13 Mar 2026 00:00:01 +0000       USD           82.6881
# AMD  Fri, 13 Mar 2026 00:00:01 +0000       USD          377.0241
# ..                               ...       ...               ...
# YER  Fri, 13 Mar 2026 00:00:01 +0000       USD          238.2992
# ZAR  Fri, 13 Mar 2026 00:00:01 +0000       USD           16.4880
# ZMW  Fri, 13 Mar 2026 00:00:01 +0000       USD           19.4838
# ZWG  Fri, 13 Mar 2026 00:00:01 +0000       USD           25.5046
# ZWL  Fri, 13 Mar 2026 00:00:01 +0000       USD           25.5046
#
# [166 rows x 9 columns]

# %% [markdown]
# ### Working With SQl

# %%
# !pip install mysql.connector
# Out:
# Collecting mysql.connector
#   Downloading mysql-connector-2.2.9.tar.gz (11.9 MB)
#      ---------------------------------------- 0.0/11.9 MB ? eta -:--:--
#      ---------------------------------------- 0.0/11.9 MB ? eta -:--:--
#       --------------------------------------- 0.3/11.9 MB ? eta -:--:--
#      - -------------------------------------- 0.5/11.9 MB 2.1 MB/s eta 0:00:06
#      -- ------------------------------------- 0.8/11.9 MB 1.2 MB/s eta 0:00:10
#      --- ------------------------------------ 1.0/11.9 MB 1.4 MB/s eta 0:00:08
#      ------ --------------------------------- 1.8/11.9 MB 1.9 MB/s eta 0:00:06
#      ------- -------------------------------- 2.4/11.9 MB 2.2 MB/s eta 0:00:05
#      --------- ------------------------------ 2.9/11.9 MB 2.2 MB/s eta 0:00:05
#      ------------ --------------------------- 3.7/11.9 MB 2.4 MB/s eta 0:00:04
#      --------------- ------------------------ 4.5/11.9 MB 2.5 MB/s eta 0:00:03
#      --------------- ------------------------ 4.7/11.9 MB 2.5 MB/s eta 0:00:03
#      ------------------ --------------------- 5.5/11.9 MB 2.6 MB/s eta 0:00:03
#      -------------------- ------------------- 6.0/11.9 MB 2.5 MB/s eta 0:00:03
#      --------------------- ------------------ 6.3/11.9 MB 2.5 MB/s eta 0:00:03
#      ----------------------- ---------------- 7.1/11.9 MB 2.6 MB/s eta 0:00:02
#      ------------------------- -------------- 7.6/11.9 MB 2.6 MB/s eta 0:00:02
#      --------------------------- ------------ 8.1/11.9 MB 2.6 MB/s eta 0:00:02
#      ----------------------------- ---------- 8.7/11.9 MB 2.6 MB/s eta 0:00:02
#      ------------------------------ --------- 9.2/11.9 MB 2.6 MB/s eta 0:00:02
#      --------------------------------- ------ 10.0/11.9 MB 2.6 MB/s eta 0:00:01
#      ----------------------------------- ---- 10.5/11.9 MB 2.7 MB/s eta 0:00:01
#      -------------------------------------- - 11.3/11.9 MB 2.7 MB/s eta 0:00:01
#      ---------------------------------------- 11.9/11.9 MB 2.7 MB/s  0:00:04
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Building wheels for collected packages: mysql.connector
#   Building wheel for mysql.connector (pyproject.toml): started
#   Building wheel for mysql.connector (pyproject.toml): finished with status 'done'
#   Created wheel for mysql.connector: filename=mysql_connector-2.2.9-cp314-cp314-win_amd64.whl size=248717 sha256=4a5e3c6d6e43e1fd9ef4357568ef2965bb5f0e35dabc625ca693a42a8fdbb2fa
#   Stored in directory: c:\users\anshuman\appdata\local\pip\cache\wheels\a2\5a\60\e03682d488f501428666827b000cfa0da00163afcd74ce2c14
# Successfully built mysql.connector
# Installing collected packages: mysql.connector
# Successfully installed mysql.connector-2.2.9
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import mysql.connector

# %%
conn = mysql.connector.connect(host='localhost',user='root',password='',database='world')

# %%
pd.read_sql_query("SELECT * FROM country",conn)
# Out:
# C:\Users\anshuman\AppData\Local\Temp\ipykernel_18796\858535147.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql_query("SELECT * FROM country",conn)
#     Code          Name      Continent                     Region  SurfaceArea  \
# 0    ABW         Aruba  North America                  Caribbean        193.0
# 1    AFG   Afghanistan           Asia  Southern and Central Asia     652090.0
# 2    AGO        Angola         Africa             Central Africa    1246700.0
# 3    AIA      Anguilla  North America                  Caribbean         96.0
# 4    ALB       Albania         Europe            Southern Europe      28748.0
# ..   ...           ...            ...                        ...          ...
# 234  YEM         Yemen           Asia                Middle East     527968.0
# 235  YUG    Yugoslavia         Europe            Southern Europe     102173.0
# 236  ZAF  South Africa         Africa            Southern Africa    1221037.0
# 237  ZMB        Zambia         Africa             Eastern Africa     752618.0
# 238  ZWE      Zimbabwe         Africa             Eastern Africa     390757.0
#
#      IndepYear  Population  LifeExpectancy       GNP    GNPOld  \
# 0          NaN      103000            78.4     828.0     793.0
# 1       1919.0    22720000            45.9    5976.0       NaN
# 2       1975.0    12878000            38.3    6648.0    7984.0
# 3          NaN        8000            76.1      63.2       NaN
# 4       1912.0     3401200            71.6    3205.0    2500.0
# ..         ...         ...             ...       ...       ...
# 234     1918.0    18112000            59.8    6041.0    5729.0
# 235     1918.0    10640000            72.4   17000.0       NaN
# 236     1910.0    40377000            51.1  116729.0  129092.0
# 237     1964.0     9169000            37.2    3377.0    3922.0
# 238     1980.0    11669000            37.8    5951.0    8670.0
#
#                  LocalName                                GovernmentForm  \
# 0                    Aruba  Nonmetropolitan Territory of The Netherlands
# 1    Afganistan/Afqanestan                               Islamic Emirate
# 2                   Angola                                      Republic
# 3                 Anguilla                 Dependent Territory of the UK
# 4                Shqipëria                                      Republic
# ..                     ...                                           ...
# 234               Al-Yaman                                      Republic
# 235            Jugoslavija                              Federal Republic
# 236           South Africa                                      Republic
# 237                 Zambia                                      Republic
# 238               Zimbabwe                                      Republic
#
#                  HeadOfState  Capital Code2
# 0                    Beatrix    129.0    AW
# 1              Mohammad Omar      1.0    AF
# 2    José Eduardo dos Santos     56.0    AO
# 3               Elisabeth II     62.0    AI
# 4             Rexhep Mejdani     34.0    AL
# ..                       ...      ...   ...
# 234       Ali Abdallah Salih   1780.0    YE
# 235       Vojislav Koštunica   1792.0    YU
# 236              Thabo Mbeki    716.0    ZA
# 237        Frederick Chiluba   3162.0    ZM
# 238         Robert G. Mugabe   4068.0    ZW
#
# [239 rows x 15 columns]
