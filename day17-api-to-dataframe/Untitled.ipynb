# %%
import pandas as pd
import requests

# %%
response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=ee95ed639bd3ca810e1d9de1461d3350&language=en-US&page=1')

# %%
response.json()
# Out:
# {'page': 1,
#  'results': [{'adult': False,
#    'backdrop_path': '/zfbjgQE1uSd9wiPTX4VzsLi0rGG.jpg',
#    'genre_ids': [18, 80],
#    'id': 278,
#    'original_language': 'en',
#    'original_title': 'The Shawshank Redemption',
#    'overview': 'Imprisoned in the 1940s for the double murder of his wife and her lover, upstanding banker Andy Dufresne begins a new life at the Shawshank prison, where he puts his accounting skills to work for an amoral warden. During his long stretch in prison, Dufresne comes to be admired by the other inmates -- including an older prisoner named Red -- for his integrity and unquenchable sense of hope.',
#    'popularity': 42.6026,
#    'poster_path': '/9cqNxx0GxF0bflZmeSMuL5tnGzr.jpg',
#    'release_date': '1994-09-23',
#    'title': 'The Shawshank Redemption',
#    'video': False,
#    'vote_average': 8.716,
#    'vote_count': 29906},
#   {'adult': False,
#    'backdrop_path': '/tSPT36ZKlP2WVHJLM4cQPLSzv3b.jpg',
#    'genre_ids': [18, 80],
# ...

# %%
df = pd.DataFrame(response.json()['results'])[['id','title','overview','release_date','popularity','vote_average','vote_count']]

# %%
df
# Out:
#          id                                          title  \
# 0       278                       The Shawshank Redemption
# 1       238                                  The Godfather
# 2       240                          The Godfather Part II
# 3       424                               Schindler's List
# 4       389                                   12 Angry Men
# 5   1181678                          ¿Quieres ser mi hijo?
# 6       129                                  Spirited Away
# 7       155                                The Dark Knight
# 8     19404                    Dilwale Dulhania Le Jayenge
# 9       497                                 The Green Mile
# 10      122  The Lord of the Rings: The Return of the King
# 11   496243                                       Parasite
# 12      680                                   Pulp Fiction
# 13   372058                                     Your Name.
# 14   157336                                   Interstellar
# ...

# %%
df = []

# %%
df
# Out:
# []

# %%
for i in range(1,537):
    response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=c75a1f21c5bd3b757c6fa22428b89c4e&language=en-US&page={}'.format(i))
    temp_df = pd.DataFrame(response.json()['results'])[['id','title','overview','release_date','popularity','vote_average','vote_count']]
    df = pd.concat([df,temp_df],ignore_index=True)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[25], line 15
#      13 for attempt in range(5):
#      14     try:
# ---> 15         response = session.get(
#      16             'https://api.themoviedb.org/3/movie/top_rated',
#      17             params={'api_key': 'c75a1f21c5bd3b757c6fa22428b89c4e', 'language': 'en-US', 'page': i},
#      18             timeout=15
#      19         )
#      20         response.raise_for_status()
#      21         temp_df = pd.DataFrame(response.json()['results'])[
#      22             ['id', 'title', 'overview', 'release_date', 'popularity', 'vote_average', 'vote_count']
#      23         ]
#
# File ~\Projects\ml-practice\.venv\Lib\site-packages\requests\sessions.py:602, in Session.get(self, url, **kwargs)
#     594 r"""Sends a GET request. Returns :class:`Response` object.
#     595
# ...

# %%
df.to_csv(movies.csv)
